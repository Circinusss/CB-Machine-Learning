# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/media/circinus/New Volume/Good Pics/2012-06-19 16.07.40.jpg')
rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (1920, 2560, 3)

# %%
plt.imshow(rgb_img)
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
crp_img = rgb_img[1000:1500,1000:1250,:]
plt.imshow(crp_img)
plt.show()

# %%
crp_img.shape
# Out:
# (500, 250, 3)

# %%
cv2.resize
# Out:
# <function resize>
