# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
from mpl_toolkits import mplot3d

# %%
X,y = make_regression(n_samples=1000,n_features=5,n_informative=1,noise=10,random_state=1)
print(X.shape,y.shape)
# Out:
# (1000, 5) (1000,)

# %%
plt.style.use('seaborn')
plt.subplot(1,2,1)
plt.scatter(X[:,0],y)
plt.subplot(1,2,2)
plt.scatter(X[:,1],y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig = plt.figure(figsize=(10,7))
ax = plt.axes(projection='3d')
#create plot
ax.scatter3D(X[:,0],X[:,1],y,color='green')
plt.title('3D Scatter Plot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# **Linear Regression using Sk-Learn**

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([87.64399715,  0.19506063])

# %%
model.intercept_
# Out:
# 0.053871487792589434

# %%
model.predict([X[0],X[1]])
# Out:
# array([-128.13010102,  -68.56133458])

# %%
y[0],y[1]
# Out:
# (-129.49142895712546, -72.90042033913113)

# %%
model.score(X,y)
# Out:
# 0.9876578548379635
